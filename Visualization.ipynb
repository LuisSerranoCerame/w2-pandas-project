# %%
### Importing libraries and necessary resources
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt

colnames=['Year', 'Country']
df = pd.read_csv("attacks.csv",encoding = "ISO-8859-1") #To load the data csv
campeonas = pd.read_csv("campeonas.csv", names=colnames, header=None,encoding = "ISO-8859-1")
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
df["Activity"]
# Out:
# 0           Paddling
# 1           Standing
# 2            Surfing
# 3            Surfing
# 4        Free diving
#             ...
# 25718            NaN
# 25719            NaN
# 25720            NaN
# 25721            NaN
# 25722            NaN
# Name: Activity, Length: 25723, dtype: object

# %%
df[["Activity","Area"]].head()
# Out:
#       Activity             Area
# 0     Paddling       California
# 1     Standing          Georgia
# 2      Surfing           Hawaii
# 3      Surfing  New South Wales
# 4  Free diving           Colima

# %%
df.Activity.unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
df.Country.unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
#        'RUSSIA', 'TURKS & CAICOS', 'UNITED ARAB EMIRATES (UAE)', 'AZORES',
#        'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR', 'PANAMA',
#        'SOMALIA', 'NEVIS', 'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL',
#        'YEMEN', 'GULF OF ADEN', 'Sierra Leone', 'ST. MAARTIN',
#        'GRAND CAYMAN', 'Seychelles', 'LIBERIA', 'VANUATU', 'MEXICO ',
#        'HONDURAS', 'VENEZUELA', 'SRI LANKA', ' TONGA', 'URUGUAY', 'INDIA',
#        'MICRONESIA', 'CARIBBEAN SEA', 'OKINAWA', 'TANZANIA',
#        'MARSHALL ISLANDS', 'EGYPT / ISRAEL', 'NORTHERN ARABIAN SEA',
#        'HONG KONG', 'EL SALVADOR', 'ANGOLA', 'BERMUDA', 'MONTENEGRO',
#        'IRAN', 'TUNISIA', 'NAMIBIA', 'NORTH ATLANTIC OCEAN', 'PORTUGAL',
#        'SOUTH CHINA SEA', 'BANGLADESH', 'PALAU', 'WESTERN SAMOA',
#        'PACIFIC OCEAN ', 'BRITISH ISLES', 'GRENADA', 'IRAQ', 'TURKEY',
#        'SINGAPORE', 'NEW BRITAIN', 'SUDAN', 'JOHNSTON ISLAND',
#        'SOUTH PACIFIC OCEAN', 'NEW GUINEA', 'RED SEA',
#        'NORTH PACIFIC OCEAN', 'FEDERATED STATES OF MICRONESIA',
#        'MID ATLANTIC OCEAN', 'ADMIRALTY ISLANDS', 'BRITISH WEST INDIES',
#        'SOUTH ATLANTIC OCEAN', 'PERSIAN GULF', 'RED SEA / INDIAN OCEAN',
#        'PACIFIC OCEAN', 'NORTH SEA', 'NICARAGUA ', 'MALDIVE ISLANDS',
#        'AMERICAN SAMOA', 'ANDAMAN / NICOBAR ISLANDAS', 'GABON', 'MAYOTTE',
#        'NORTH ATLANTIC OCEAN ', 'THE BALKANS', 'SUDAN?', 'ARGENTINA',
#        'MARTINIQUE', 'INDIAN OCEAN', 'GUATEMALA', 'NETHERLANDS ANTILLES',
#        'NORTHERN MARIANA ISLANDS', 'IRAN / IRAQ', 'JAVA', 'SIERRA LEONE',
#        ' PHILIPPINES', 'NICARAGUA', 'CENTRAL PACIFIC',
#        'SOLOMON ISLANDS / VANUATU', 'SOUTHWEST PACIFIC OCEAN',
#        'BAY OF BENGAL', 'MID-PACIFC OCEAN', 'SLOVENIA', 'CURACAO',
#        'ICELAND', 'ITALY / CROATIA', 'BARBADOS', 'MONACO', 'GUYANA',
#        'HAITI', 'SAN DOMINGO', 'IRELAND', 'KUWAIT', 'YEMEN ',
#        'REUNION ISLAND', 'FALKLAND ISLANDS', 'CRETE', 'CYPRUS', 'EGYPT ',
#        'WEST INDIES', 'BURMA', 'LEBANON', 'PARAGUAY',
#        'BRITISH NEW GUINEA', 'CEYLON', 'OCEAN', 'GEORGIA', 'SYRIA',
#        'TUVALU', 'INDIAN OCEAN?', 'GUINEA', 'ANDAMAN ISLANDS',
#        'EQUATORIAL GUINEA / CAMEROON', 'COOK ISLANDS', 'TOBAGO', 'PERU',
#        'AFRICA', 'ALGERIA', 'Coast of AFRICA', 'TASMAN SEA', 'GHANA',
#        'GREENLAND', 'MEDITERRANEAN SEA', 'SWEDEN', 'ROATAN',
#        'Between PORTUGAL & INDIA', 'DJIBOUTI', 'BAHREIN', 'KOREA',
#        'RED SEA?', 'ASIA?', 'CEYLON (SRI LANKA)'], dtype=object)

# %%
#### Limpia de los datos relacionados con USA

# %%
"""
Identificando que hay suficiente información en la muestra 
y creando un nuevo dataframe para trabajar sobre él
"""
surf_usa = df[(df.Country=="USA")&(df.Activity == "Surfing" )]
surf_usa.shape
# Out:
# (564, 24)

# %%
surf_usa.count()
# Out:
# Case Number               564
# Date                      564
# Year                      564
# Type                      564
# Country                   564
# Area                      564
# Location                  560
# Activity                  564
# Name                      557
# Sex                       545
# Age                       476
# Injury                    560
# Fatal (Y/N)               538
# Time                      454
# Species                   332
# Investigator or Source    562
# pdf                       564
# href formula              564
# href                      564
# Case Number.1             564
# Case Number.2             564
# original order            564
# Unnamed: 22                 1
# Unnamed: 23                 0
# dtype: int64

# %%
#Elimino columnas sin información
surf_usa.drop(["Unnamed: 22","Unnamed: 23"],axis=1,inplace = True)
display(surf_usa)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Case Number          Date    Year        Type Country        Area  \
# 2       2018.06.09   09-Jun-2018  2018.0     Invalid     USA      Hawaii
# 53      2017.12.31   31-Dec-2017  2017.0  Unprovoked     USA      Hawaii
# 54      2017.12.30   30-Dec-2017  2017.0  Unprovoked     USA  California
# 61      2017.11.18   18-Nov-2017  2017.0  Unprovoked     USA     Florida
# 74      2017.10.09   09-Oct-2017  2017.0  Unprovoked     USA      Hawaii
# ...            ...           ...     ...         ...     ...         ...
# 3643  1965.00.00.f          1965  1965.0    Provoked     USA  California
# 4284  1955.08.30.a   30-Aug-1955  1955.0    Provoked     USA  California
# 6097    1828.00.00          1828  1828.0  Unprovoked     USA      Hawaii
# 6143    1779.00.00          1779  1779.0  Unprovoked     USA      Hawaii
# 6201       ND-0122  Beforer 1994     0.0  Unprovoked     USA     Florida
#
#                                           Location Activity              Name  \
# 2                                     Habush, Oahu  Surfing       John Denges
# 53                            Hultin's Beach, Oahu  Surfing  Marjorie Mariano
# 54        Drakes Estero, Point Reyes, Marin County  Surfing     Natalie Jones
# 61                 Floridana Beach, Brevard County  Surfing     Kaia Anderson
# 74                  Davidsons Beach, Kekaha, Kauai  Surfing       Mitch Milan
# ...                                            ...      ...               ...
# 3643       Dana Point, San Clemente, Orange County  Surfing        Barry Berg
# 4284  Zuma Beach, Santa Monica, Los Angeles County  Surfing       Dale Strand
# 6097                             Uo, Lahaina, Maui  Surfing              Male
# 6143                                Maliu, Hawai'i  Surfing  Nu'u-anu-pa'a hu
# 6201          Lost Tree Village, Palm Beach County  Surfing               C.M
#
#      Sex   ... Fatal (Y/N)            Time  \
# 2       M  ...           N           07h45
# 53      F  ...           N           18h00
# 54      F  ...           N           12h00
# 61      F  ...           N  Late afternoon
# 74      M  ...           N           18h30
# ...   ...  ...         ...             ...
# 3643    M  ...           N             NaN
# 4284    M  ...           N             NaN
# 6097    M  ...           Y             NaN
# 6143    M  ...           Y             NaN
# 6201    M  ...           N             NaN
#
#                                                Species   \
# 2                                                   NaN
# 53                                          Tiger shark
# 54                                                  NaN
# 61                                                  NaN
# 74                            Tiger shark, 8 to 10 feet
# ...                                                 ...
# 3643                                                NaN
# 4284  5' thresher or blue shark. The shark  was kill...
# 6097                                                NaN
# 6143                                                NaN
# 6201                                                NaN
#
#                                  Investigator or Source  \
# 2                        K.McMurray, TrackingSharks.com
# 53                    J. Howard, Surfling Now, 1/2/2018
# 54                                           R. Collier
# 61                            Florida Today, 11/21/2017
# 74                          Hawaii News Now, 10/10/2017
# ...                                                 ...
# 3643                  Orange County Register, 1/28/2998
# 4284  SAF Case #244; D. Miller & R. Collier, V.M. Co...
# 6097          J. Borg, p.68; L. Taylor (1993), pp.94-95
# 6143  G.H. Balazs; J. Borg, p.68; L. Taylor (1993), ...
# 6201                                 M. Vorenberg, GSAF
#
#                               pdf  \
# 2           2018.06.09-Denges.pdf
# 53         2017.12.31-Mariano.pdf
# 54           2017.12.30.Jones.pdf
# 61        2017.11.18-Anderson.pdf
# 74           2017.10.09-Milan.pdf
# ...                           ...
# 3643        1965.00.00.f-Berg.pdf
# 4284  1955.08.30.a-DaleStrand.pdf
# 6097          1828.00.00-male.pdf
# 6143        1779.00.00-Hawaii.pdf
# 6201               ND-0122-CM.pdf
#
#                                            href formula  \
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 53    http://sharkattackfile.net/spreadsheets/pdf_di...
# 54    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 74    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 3643  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4284  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6097  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6143  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6201  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 53    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.12.31
# 54    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.12.30
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.11.18
# 74    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.09
# ...                                                 ...           ...
# 3643  http://sharkattackfile.net/spreadsheets/pdf_di...  1965.00.00.f
# 4284  http://sharkattackfile.net/spreadsheets/pdf_di...  1955.08.30.a
# 6097  http://sharkattackfile.net/spreadsheets/pdf_di...    1828.00.00
# 6143  http://sharkattackfile.net/spreadsheets/pdf_di...    1779.00.00
# 6201  http://sharkattackfile.net/spreadsheets/pdf_di...       ND-0122
#
#      Case Number.2 original order
# 2       2018.06.09         6301.0
# 53      2017.12.31         6250.0
# 54      2017.12.30         6249.0
# 61      2017.11.18         6242.0
# 74      2017.10.09         6229.0
# ...            ...            ...
# 3643  1965.00.00.f         2660.0
# 4284  1955.08.30.a         2019.0
# 6097    1828.00.00          206.0
# 6143    1779.00.00          160.0
# 6201       ND-0122          102.0
#
# [564 rows x 22 columns]

# %%
#Analizo la columna Type para revisar el tipo de ataques
surf_usa.loc[surf_usa["Type"] == "Unprovoked"].sample(20)
# Out:
#        Case Number         Date    Year        Type Country        Area  \
# 522     2014.08.02  02-Aug-2014  2014.0  Unprovoked     USA     Florida
# 1470    2006.06.20  20-Jun-2006  2006.0  Unprovoked     USA     Florida
# 2220    1997.10.21  21-Oct-1997  1997.0  Unprovoked     USA     Florida
# 3227    1975.05.25  25-May-1975  1975.0  Unprovoked     USA     Florida
# 2795    1986.12.11  11-Dec-1986  1986.0  Unprovoked     USA     Florida
# 1957  2001.04.12.c  12-Apr-2001  2001.0  Unprovoked     USA     Florida
# 826     2012.01.13  13-Jan-2012  2012.0  Unprovoked     USA      Oregon
# 2433  1994.05.31.b  31-May-1994  1994.0  Unprovoked     USA     Florida
# 61      2017.11.18  18-Nov-2017  2017.0  Unprovoked     USA     Florida
# 2177    1998.07.25  25-Jul-1998  1998.0  Unprovoked     USA     Florida
# 1921  2001.08.18.c  18-Aug-2001  2001.0  Unprovoked     USA     Florida
# 868   2011.09.11.b  11-Sep-2011  2011.0  Unprovoked     USA  California
# 2272    1996.11.18  18-Nov-1996  1996.0  Unprovoked     USA     Florida
# 2337  1995.09.30.b  30-Sep-1995  1995.0  Unprovoked     USA     Florida
# 737     2012.09.24  24-Sep-2012  2012.0  Unprovoked     USA     Florida
# 1205    2008.09.08  08-Sep-2008  2008.0  Unprovoked     USA  California
# 1264  2008.04.28.a  28-Apr-2008  2008.0  Unprovoked     USA     Florida
# 1286    2008.03.07  07-Mar-2008  2008.0  Unprovoked     USA  California
# 723     2012.11.19  19-Nov-2012  2012.0  Unprovoked     USA     Florida
# 1742  2003.09.14.c  14-Sep-2003  2003.0  Unprovoked     USA     Florida
#
#                                                Location Activity  \
# 522                South of Cocoa Beach, Brevard County  Surfing
# 1470                   New Smyrna Beach, Volusia County  Surfing
# 2220  North Jetty, Fort Pierce Inlet State Park, St....  Surfing
# 3227                   New Smyrna Beach, Volusia County  Surfing
# 2795      Ponce Inlet, New Smyrna Beach, Volusia County  Surfing
# 1957                   New Smyrna Beach, Volusia County  Surfing
# 826                        Lincoln City, Lincoln County  Surfing
# 2433                        Ponce Inlet, Volusia County  Surfing
# 61                      Floridana Beach, Brevard County  Surfing
# 2177                   New Smyrna Beach, Volusia County  Surfing
# 1921                   New Smyrna Beach, Volusia County  Surfing
# 868                        Samoa Beach, Humboldt County  Surfing
# 2272                 Coral Cove Park, Palm Beach County  Surfing
# 2337    Crescent Beach, St. Augustine, St. Johns County  Surfing
# 737                 Spanish House Beach, Brevard County  Surfing
# 1205           Surf Beach, Lompoc, Santa Barbara County  Surfing
# 1264                   New Smyrna Beach, Volusia County  Surfing
# 1286                    Huntington Beach, Orange County  Surfing
# 723                     Melbourne Beach, Brevard County  Surfing
# 1742                   New Smyrna Beach, Volusia County  Surfing
#
#                   Name Sex   ... Fatal (Y/N)            Time  \
# 522               male    M  ...           N             NaN
# 1470  Elizabeth Schelk    F  ...           N           13h00
# 2220       Jacob McBee    M  ...           N           18h00
# 3227    Edward Bassett    M  ...           N           10h00
# 2795     Bob Earnhardt    M  ...           N           14h00
# 1957    Emmet Browning    M  ...           N           16h05
# 826      Steve Harnack    M  ...           N             NaN
# 2433      Steve Polack    M  ...           N           10h30
# 61       Kaia Anderson    F  ...           N  Late afternoon
# 2177     Michael Rinto    M  ...           N            P.M.
# 1921        Jeff White    M  ...           N           12h30
# 868        Benjie Rose    M  ...           N           12h20
# 2272       Adam Urban     M  ...           N           17h00
# 2337         Jon Grace    M  ...           N         Morning
# 737     Brandon Murray    M  ...           N       Afternoon
# 1205           Kyle K.    M  ...           N           10h30
# 1264       David Alger    M  ...           N           11h45
# 1286     Thomas Larkin    M  ...           N           08h00
# 723       Kai Rittgers    M  ...           N           17h30
# 1742    Jason Williams    M  ...           N           16h14
#
#                                                Species   \
# 522                                                 NaN
# 1470      Possibly a 1' to 3' blacktip or spinner shark
# 2220                    1.2 m to 1.5 m [4' to 5'] shark
# 3227                                                NaN
# 2795  1.8 m to 2.1 m [6' to 7'] spinner or blacktip ...
# 1957      Possibly a juvenile blacktip or spinner shark
# 826                                         White shark
# 2433                                                NaN
# 61                                                  NaN
# 2177                                                NaN
# 1921              Possibly  a blacktip or spinner shark
# 868                                                 NaN
# 2272                                                NaN
# 2337                      1.5 to 1.8 m [5' to 6'] shark
# 737                                            4' shark
# 1205                           White shark, 14' to 16'
# 1264                                           4' shark
# 1286                                        White shark
# 723                                      2' to 3' shark
# 1742                                           3' shark
#
#                                  Investigator or Source  \
# 522                             Florida Today, 8/8/2014
# 1470                      S. Petersohn, GSAF; P. Immerz
# 2220                Fort Pierce News,  10/24/1997, p.A2
# 3227                        Sumter Daily Item, 7/9/1975
# 2795                 Orlando Sentinel, 12/12/1986, p.A1
# 1957  S. Petersohn, GSAF; Orlando Sentinel, 4/14/200...
# 826                                          R. Collier
# 2433    C. Lancaster, Orlando Sentinel,  6/1/1994, p.C1
# 61                            Florida Today, 11/21/2017
# 2177  S. Petersohn, GSAF; Orlando Sentinel, 7/24/199...
# 1921  S. Petersohn, GSAF; Orlando Sentinel, 8/20/200...
# 868                                          R. Collier
# 2272                        Jupiter Courier, 11/20/1996
# 2337                    St. Petersburg Times, 10/3/1995
# 737                                  TC Palm, 9/26/2012
# 1205                                         R. Collier
# 1264                                       S. Petersohn
# 1286                                         R. Collier
# 723                           Florida Today, 11/19/2012
# 1742                                 S. Petersohn, GSAF
#
#                                  pdf  \
# 522        2014.08.08-CocoaBeach.pdf
# 1470           2006.06.20-Schelk.pdf
# 2220            1997.10.21-McBee.pdf
# 3227          1975.05.25-Bassett.pdf
# 2795        1986.12.11-Earnhardt.pdf
# 1957       2001.04.12.c-Browning.pdf
# 826           2012.01.13-Harnack.pdf
# 2433         1994.05.31.b-Polack.pdf
# 61           2017.11.18-Anderson.pdf
# 2177            1998.07.25-Rinto.pdf
# 1921          2001.08.18.c-White.pdf
# 868      2011.09.11.b-Benji-Rose.pdf
# 2272            1996.11.18-Urban.pdf
# 2337          1995.09.30.b-Grace.pdf
# 737            2012.09.24-Murray.pdf
# 1205             2008.09.08-Kyle.pdf
# 1264          2008.04.28.a-Alger.pdf
# 1286           2008.03.07-Larkin.pdf
# 723          2012.11.19-Rittgers.pdf
# 1742  2003.09.14.c-JasonWilliams.pdf
#
#                                            href formula  \
# 522   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1470  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2220  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3227  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2795  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1957  http://sharkattackfile.net/spreadsheets/pdf_di...
# 826   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2433  http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2177  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1921  http://sharkattackfile.net/spreadsheets/pdf_di...
# 868   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2272  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2337  http://sharkattackfile.net/spreadsheets/pdf_di...
# 737   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1205  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1264  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1286  http://sharkattackfile.net/spreadsheets/pdf_di...
# 723   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1742  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 522   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.08.02
# 1470  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.06.20
# 2220  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.10.21
# 3227  http://sharkattackfile.net/spreadsheets/pdf_di...    1975.05.25
# 2795  http://sharkattackfile.net/spreadsheets/pdf_di...    1986.12.11
# 1957  http://sharkattackfile.net/spreadsheets/pdf_di...  2001.04.12.c
# 826   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.01.13
# 2433  http://sharkattackfile.net/spreadsheets/pdf_di...  1994.05.31.b
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.11.18
# 2177  http://sharkattackfile.net/spreadsheets/pdf_di...    1998.07.25
# 1921  http://sharkattackfile.net/spreadsheets/pdf_di...  2001.08.18.c
# 868   http://sharkattackfile.net/spreadsheets/pdf_di...  2011.09.11.b
# 2272  http://sharkattackfile.net/spreadsheets/pdf_di...    1996.11.18
# 2337  http://sharkattackfile.net/spreadsheets/pdf_di...  1995.09.30.b
# 737   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.09.24
# 1205  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.09.08
# 1264  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.28.a
# 1286  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.03.07
# 723   http://sharkattackfile.net/spreadsheets/pdf_di...    2012.11.19
# 1742  http://sharkattackfile.net/spreadsheets/pdf_di...  2003.09.14.c
#
#      Case Number.2 original order
# 522     2014.08.02         5781.0
# 1470    2006.06.20         4833.0
# 2220    1997.10.21         4083.0
# 3227    1975.05.25         3076.0
# 2795    1986.12.11         3508.0
# 1957  2001.04.12.c         4346.0
# 826     2012.01.13         5477.0
# 2433  1994.05.31.b         3870.0
# 61      2017.11.18         6242.0
# 2177    1998.07.25         4126.0
# 1921  2001.08.18.c         4382.0
# 868   2011.09.11.b         5435.0
# 2272    1996.11.18         4031.0
# 2337  1995.09.30.b         3966.0
# 737     2012.09.24         5566.0
# 1205    2008.09.08         5098.0
# 1264  2008.04.28.a         5039.0
# 1286    2008.03.07         5017.0
# 723     2012.11.19         5580.0
# 1742  2003.09.14.c         4561.0
#
# [20 rows x 22 columns]

# %%
#Utilizo unique para saber los valores únicos de la columna Year y poder depurarla
surf_usa["Year"].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1994., 1993., 1992.,
#        1991., 1990., 1989., 1988., 1987., 1986., 1985., 1984., 1983.,
#        1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975., 1974.,
#        1973., 1972., 1971., 1970., 1969., 1968., 1967., 1965., 1955.,
#        1828., 1779.,    0.])

# %%
#Confirmo los valores que no me valen para el estudio y los elimino por ser muy antiguos.
surf_usa.loc[surf_usa["Year"] == 0].sample(1)
surf_usa.loc[surf_usa["Year"] == 1779].sample()
surf_usa.loc[surf_usa["Year"] == 1828].sample(1)
surf_usa.drop([6201],axis=0,inplace=True)
surf_usa.drop([6097],axis=0,inplace=True)
surf_usa.drop([6143],axis=0,inplace=True)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Reviso la columna Fatal (Y/N) ya que creo que puede ser interesante.
surf_usa["Fatal (Y/N)"].unique()
# Out:
# array(['N', nan, 'Y', 'UNKNOWN'], dtype=object)

# %%
#Cambio el nombre de la columna
surf_usa.rename(columns={"Fatal (Y/N)":"Fatal"},inplace=True)
surf_usa["Fatal"].unique()
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# array(['N', nan, 'Y', 'UNKNOWN'], dtype=object)

# %%
surf_usa.loc[surf_usa["Fatal"] == "UNKNOWN"].sample(3)
surf_usa["Fatal"].isna().sum()
# Out:
# 26

# %%
#Completo las casillas vacías con un valor para ubicarlos y uso str.replace con el mismo valor
surf_usa['Fatal'] = surf_usa['Fatal'].fillna('U')
surf_usa['Fatal'] = surf_usa['Fatal'].str.replace('UNKNOWN', 'U')
# Out:
# <ipython-input-67-916d0350b5ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_usa['Fatal'] = surf_usa['Fatal'].fillna('U')
# <ipython-input-67-916d0350b5ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_usa['Fatal'] = surf_usa['Fatal'].str.replace('UNKNOWN', 'U')

# %%
#Reviso la acción anterior, dejnado la columna con solo tres valores posibles
surf_usa["Fatal"].unique()
# Out:
# array(['N', 'U', 'Y'], dtype=object)

# %%
#Reviso los valores de la columna "Sex " ya que me va a servir para la segunda hipótesis
surf_usa["Sex "].unique()
# Out:
# array(['M', 'F', nan, 'lli'], dtype=object)

# %%
#Corrijo el nombre de la columna
surf_usa.rename(columns={"Sex ":"Sex"},inplace=True)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Corrijo los valores que no conocemos para que tengan el mismo nombre 
surf_usa['Sex'] = surf_usa['Sex'].fillna('U')
surf_usa['Sex'] = surf_usa['Sex'].str.replace('lli', 'U')
# Out:
# <ipython-input-74-847bf6901614>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_usa['Sex'] = surf_usa['Sex'].fillna('U')
# <ipython-input-74-847bf6901614>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_usa['Sex'] = surf_usa['Sex'].str.replace('lli', 'U')

# %%
#Reviso que la acción anterior está bien ejecutada.
surf_usa["Sex"].unique()
# Out:
# array(['M', 'F', 'U'], dtype=object)

# %%
#### Limpia de datos referentes a Australia
# Out:
#        Case Number                  Date    Year        Type Country  \
# 265     2016.06.07           07-Jun-2016  2016.0     Invalid     USA
# 2454  1994.01.31.a           31-Jan-1994  1994.0  Unprovoked     USA
# 1312    2007.11.04           04-Nov-2007  2007.0  Unprovoked     USA
# 1532  2005.11.02.a           02-Nov-2005  2005.0  Unprovoked     USA
# 1537    2005.10.19           19-Oct-2005  2005.0  Unprovoked     USA
# 2988    1982.02.27           27-Feb-1982  1982.0  Unprovoked     USA
# 2225    1997.09.08           08-Sep-1997  1997.0  Unprovoked     USA
# 1742  2003.09.14.c           14-Sep-2003  2003.0  Unprovoked     USA
# 1520  2005.11.29.R  Reported 29-Nov-2005  2005.0  Unprovoked     USA
# 2227    1997.08.30           30-Aug-1997  1997.0  Unprovoked     USA
#
#                 Area                                          Location  \
# 265   South Carolina                    Folly Beach, Charleston County
# 2454          Hawaii                   Velzyland, north shore of O'ahu
# 1312         Florida            Round Island Park, Indian River County
# 1532      California  Ocean Beach, San Francisco, San Francisco County
# 1537      California                       Salmon Beach, Sonoma County
# 2988         Florida                     Hobe Sound, Palm Beach County
# 2225         Florida                  New Smyrna Beach, Volusia County
# 1742         Florida                  New Smyrna Beach, Volusia County
# 1520         Florida                        Cape San Blas, Gulf County
# 2227         Florida                  New Smyrna Beach, Volusia County
#
#      Activity            Name Sex  ... Fatal     Time  \
# 265   Surfing    Jack O'Neill   M  ...     U    11h30
# 2454  Surfing      Jim Broach   M  ...     Y      NaN
# 1312  Surfing   Jeffrey Nolan   M  ...     N    09h00
# 1532  Surfing    Jake Daneman   M  ...     N    07h15
# 1537  Surfing  Megan Halavais   F  ...     N    10h30
# 2988  Surfing   Richard Bauer   M  ...     N      NaN
# 2225  Surfing            male   U  ...     N  Evening
# 1742  Surfing  Jason Williams   M  ...     N    16h14
# 1520  Surfing     John Larsen   M  ...     N      NaN
# 2227  Surfing     Chris Hoyas   M  ...     N    13h00
#
#                                                Species   \
# 265   Said to involve an 8' shark but more likely da...
# 2454                                        Tiger shark
# 1312                                           5' shark
# 1532                             12' to 14' white shark
# 1537                                    18' white shark
# 2988                                     4' to 5' shark
# 2225                               small blacktip shark
# 1742                                           3' shark
# 1520                                                NaN
# 2227                                                NaN
#
#                    Investigator or Source                             pdf  \
# 265                     C. Creswell, GSAF           2016.06.07-Oneill.pdf
# 2454              G. Balazs; Allen, p.109         1994.01.31.a-Broach.pdf
# 1312     T.C. Palm, 11/4/2007 & 11/5/2007            2007.11.04-Nolan.pdf
# 1532                     R. Collier, GSAF        2005.11.02.a-Daneman.pdf
# 1537  R. Collier, GSAF; Bay City Newswire         2005.10.19-Halavais.pdf
# 2988         Palm Beach Post, 3/2/1982               1982.02.27-Bauer.pdf
# 2225       Daytona News-Journal, 9/9/1997              1997.09.08-NSB.pdf
# 1742                   S. Petersohn, GSAF  2003.09.14.c-JasonWilliams.pdf
# 1520                             wpmi.com         2005.11.29.R-Larsen.pdf
# 2227                   S. Petersohn, GSAF            1997.08.30-Hoyas.pdf
#
#                                            href formula  \
# 265   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2454  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1312  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1532  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1537  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2988  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2225  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1742  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1520  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2227  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 265   http://sharkattackfile.net/spreadsheets/pdf_di...    2016.06.07
# 2454  http://sharkattackfile.net/spreadsheets/pdf_di...  1994.01.31.a
# 1312  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.11.04
# 1532  http://sharkattackfile.net/spreadsheets/pdf_di...  2005.11.02.a
# 1537  http://sharkattackfile.net/spreadsheets/pdf_di...    2005.10.19
# 2988  http://sharkattackfile.net/spreadsheets/pdf_di...    1982.02.27
# 2225  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.09.08
# 1742  http://sharkattackfile.net/spreadsheets/pdf_di...  2003.09.14.c
# 1520  http://sharkattackfile.net/spreadsheets/pdf_di...  2005.11.29.R
# 2227  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.08.30
#
#      Case Number.2 original order
# 265     2016.06.07         6038.0
# 2454  1994.01.31.a         3849.0
# 1312    2007.11.04         4991.0
# 1532  2005.11.02.a         4771.0
# 1537    2005.10.19         4766.0
# 2988    1982.02.27         3315.0
# 2225    1997.09.08         4078.0
# 1742  2003.09.14.c         4561.0
# 1520  2005.11.29.R         4783.0
# 2227    1997.08.30         4076.0
#
# [10 rows x 22 columns]

# %%
# Declaro un nuevo set para comparar los datos de usa con los de Australia
surf_aus = df[(df.Country=="AUSTRALIA")&(df.Activity == "Surfing" )]
surf_aus.shape
# Out:
# (195, 24)

# %%
#Borro las columnas que no tienen información
surf_aus.drop(["Unnamed: 22","Unnamed: 23"],axis=1,inplace = True)
display(surf_aus)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Case Number         Date    Year          Type    Country  \
# 3       2018.06.08  08-Jun-2018  2018.0    Unprovoked  AUSTRALIA
# 16      2018.05.09  09-May-2018  2018.0  Questionable  AUSTRALIA
# 19    2018.04.28.a  28-Apr-2018  2018.0    Unprovoked  AUSTRALIA
# 20    2018.04.25.b  25-Apr-2018  2018.0  Questionable  AUSTRALIA
# 21    2018.04.25.a  25-Apr-2018  2018.0    Unprovoked  AUSTRALIA
# ...            ...          ...     ...           ...        ...
# 4657    1944.01.14  14-Jan-1944  1944.0    Unprovoked  AUSTRALIA
# 4890    1936.01.05  05-Jan-1936  1936.0       Invalid  AUSTRALIA
# 4917    1935.03.11  11-Mar-1935  1935.0    Unprovoked  AUSTRALIA
# 5235    1922.01.04  04-Jan-1922  1922.0    Unprovoked  AUSTRALIA
# 5280    1918.03.22  22-Mar-1918  1918.0    Unprovoked  AUSTRALIA
#
#                    Area                   Location Activity  \
# 3       New South Wales         Arrawarra Headland  Surfing
# 16      New South Wales     Sharpes Beach, Ballina  Surfing
# 19    Western Australia               Gearys Beach  Surfing
# 20      New South Wales                Lennox Head  Surfing
# 21    Western Australia    Surfers Point, Prevelly  Surfing
# ...                 ...                        ...      ...
# 4657    New South Wales       First Beach, Forster  Surfing
# 4890         Queensland      Main Beach, Southport  Surfing
# 4917    New South Wales                  Newcastle  Surfing
# 5235    New South Wales  Stockton Beach, Newcastle  Surfing
# 5280    New South Wales                  Newcastle  Surfing
#
#                    Name Sex   ... Fatal (Y/N)     Time  \
# 3                  male    M  ...           N      NaN
# 16                 male    M  ...           N    10h30
# 19          Adam Murray    M  ...           N    16h50
# 20          Matthew Lee    M  ...           N    07h00
# 21            Rob Bruce    M  ...           N    09h30
# ...                 ...  ...  ...         ...      ...
# 4657         Peter Weir    M  ...           N    17h00
# 4890      Kevin Canavan    M  ...         NaN      NaN
# 4917     Eric McMichael    M  ...           N      NaN
# 5235  John Manning Rowe    M  ...           Y  Evening
# 5280        Arthur Cook    M  ...           N    18h00
#
#                                                Species   \
# 3                                             2 m shark
# 16                      Shark involvement not confirmed
# 19                                                  NaN
# 20                                         Questionable
# 21                                            3 m shark
# ...                                                 ...
# 4657                                                NaN
# 4890  Shark involvement prior to death was not confi...
# 4917                                                NaN
# 5235                                                NaN
# 5280                                          12' shark
#
#                                  Investigator or Source  \
# 3                                        B. Myatt, GSAF
# 16                                       B. Myatt, GSAF
# 19                                       B. Myatt, GSAF
# 20                                       B. Myatt, GSAF
# 21                                        B.Myatt, GSAF
# ...                                                 ...
# 4657  G.P. Whitley (1951), p.193, cites Daily Mirror...
# 4890  Canberra Times, 1/7/1936; V.M. Coppleson, p.92-93
# 4917                   Sydney Morning Herald, 3/11/1935
# 5235    The Argus, 1/9/1922; V.M. Coppleson (1933), N15
# 5280                          The Advertiser, 3/25/1918
#
#                               pdf  \
# 3        2018.06.08-Arrawarra.pdf
# 16    2018.05.09-SharpesBeach.pdf
# 19        2018.04.28.a-Murray.pdf
# 20           2018.04.25.b-Lee.pdf
# 21         2018.04.25.a-Bruce.pdf
# ...                           ...
# 4657          1944.01.14-Weir.pdf
# 4890       1936.01.05-Canavan.pdf
# 4917     1935.03.11-McMichael.pdf
# 5235  1922.01.04-JManningRowe.pdf
# 5280          1918.03.22-Cook.pdf
#
#                                            href formula  \
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 16    http://sharkattackfile.net/spreadsheets/pdf_di...
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 4657  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4890  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4917  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5235  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5280  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 16    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.09
# 19    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.28.a
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.25.b
# 21    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.25.a
# ...                                                 ...           ...
# 4657  http://sharkattackfile.net/spreadsheets/pdf_di...    1944.01.14
# 4890  http://sharkattackfile.net/spreadsheets/pdf_di...    1936.01.05
# 4917  http://sharkattackfile.net/spreadsheets/pdf_di...    1935.03.11
# 5235  http://sharkattackfile.net/spreadsheets/pdf_di...    1922.01.04
# 5280  http://sharkattackfile.net/spreadsheets/pdf_di...    1918.03.22
#
#      Case Number.2 original order
# 3       2018.06.08         6300.0
# 16      2018.05.09         6287.0
# 19    2018.04.28.a         6284.0
# 20    2018.04.25.b         6283.0
# 21    2018.04.25.a         6282.0
# ...            ...            ...
# 4657    1944.01.14         1646.0
# 4890    1936.01.05         1413.0
# 4917    1935.03.11         1386.0
# 5235    1922.01.04         1068.0
# 5280    1918.03.22         1023.0
#
# [195 rows x 22 columns]

# %%
#Modifico el nombre de la columna Fatal (Y/N)
surf_aus.rename(columns={"Fatal (Y/N)":"Fatal"},inplace=True)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Modifico los valores vacíos y los UNKNOWN a una variable que conocemos.
surf_aus['Fatal'] = surf_aus['Fatal'].fillna('U')
surf_aus['Fatal'] = surf_aus['Fatal'].str.replace('UNKNOWN', 'U')
# Out:
# <ipython-input-60-ae72b4437eb0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_aus['Fatal'] = surf_aus['Fatal'].fillna('U')
# <ipython-input-60-ae72b4437eb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_aus['Fatal'] = surf_aus['Fatal'].str.replace('UNKNOWN', 'U')

# %%
#Revisamos que se ha realizado correctamente.
surf_aus["Fatal"].unique()
# Out:
# array(['N', 'Y', 'U'], dtype=object)

# %%
#Reviso los valores de la columna "Sex "
surf_aus["Sex "].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
#Corrijo el nombre de la columna
surf_aus.rename(columns={"Sex ":"Sex"},inplace=True)
# Out:
# /home/luisserrano/.local/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Modifico los valores vacíos por un valor conocido
surf_aus['Sex'] = surf_aus['Sex'].fillna('U')
# Out:
# <ipython-input-82-80c0f0b513b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   surf_aus['Sex'] = surf_aus['Sex'].fillna('U')

# %%
#Revisamos que se ha realizado correctamente.
surf_aus["Sex"].unique()
# Out:
# array(['M', 'F', 'U'], dtype=object)

# %%
#### Limpia Dataset importado para comprobar las hipótesis

# %%
#Revisamos el dataset que hemos importado de excel sobre el que vamos a contrastar los datos.
display(campeonas)
# Out:
#         Year  Country
# 0   2019;USA      NaN
# 1   2018;AUS      NaN
# 2   2017;AUS      NaN
# 3   2016;AUS      NaN
# 4   2015;USA      NaN
# 5   2014;AUS      NaN
# 6   2013;USA      NaN
# 7   2012;AUS      NaN
# 8   2011;USA      NaN
# 9   2010;AUS      NaN
# 10  2009;AUS      NaN
# 11  2008;AUS      NaN
# 12  2007;AUS      NaN
# 13  2006;AUS      NaN
# 14  2005;AUS      NaN
# 15  2003;AUS      NaN
# 16  2002;AUS      NaN
# 17  2001;AUS      NaN
# 18  2000;AUS      NaN
# 19  1999;AUS      NaN
# 20  1998;AUS      NaN
# 21  1997;USA      NaN
# 22  1996;USA      NaN
# 23  1995;USA      NaN
# 24  1994;USA      NaN
# 25  1993;AUS      NaN
# 26  1992;AUS      NaN
# 27  1991;AUS      NaN
# 28  1990;AUS      NaN
# 29  1989;AUS      NaN
# 30  1988;AUS      NaN
# 31  1987;AUS      NaN
# 32  1986;AUS      NaN
# 33  1985;AUS      NaN
# 34  1984;AUS      NaN
# 35  1982;USA      NaN
# 36  1981;USA      NaN
# 37  1980;USA      NaN
# 38  1979;USA      NaN
# 39  1978;USA      NaN
# 40  1977;USA      NaN
# 41  1972;USA      NaN
# 42  1970;USA      NaN
# 43  1968;USA      NaN
# 44  1966;USA      NaN
# 45  1965;USA      NaN
# 46  1964;AUS      NaN

# %%
#Usamos el método str.split para dividir en columnas los datos que residen en una misma string
campeonas[["Years","Countries"]] = campeonas["Year"].str.split(";",expand=True)
display(campeonas)
# Out:
#         Year  Country Years Countries
# 0   2019;USA      NaN  2019       USA
# 1   2018;AUS      NaN  2018       AUS
# 2   2017;AUS      NaN  2017       AUS
# 3   2016;AUS      NaN  2016       AUS
# 4   2015;USA      NaN  2015       USA
# 5   2014;AUS      NaN  2014       AUS
# 6   2013;USA      NaN  2013       USA
# 7   2012;AUS      NaN  2012       AUS
# 8   2011;USA      NaN  2011       USA
# 9   2010;AUS      NaN  2010       AUS
# 10  2009;AUS      NaN  2009       AUS
# 11  2008;AUS      NaN  2008       AUS
# 12  2007;AUS      NaN  2007       AUS
# 13  2006;AUS      NaN  2006       AUS
# 14  2005;AUS      NaN  2005       AUS
# 15  2003;AUS      NaN  2003       AUS
# 16  2002;AUS      NaN  2002       AUS
# 17  2001;AUS      NaN  2001       AUS
# 18  2000;AUS      NaN  2000       AUS
# 19  1999;AUS      NaN  1999       AUS
# 20  1998;AUS      NaN  1998       AUS
# 21  1997;USA      NaN  1997       USA
# 22  1996;USA      NaN  1996       USA
# 23  1995;USA      NaN  1995       USA
# 24  1994;USA      NaN  1994       USA
# 25  1993;AUS      NaN  1993       AUS
# 26  1992;AUS      NaN  1992       AUS
# 27  1991;AUS      NaN  1991       AUS
# 28  1990;AUS      NaN  1990       AUS
# 29  1989;AUS      NaN  1989       AUS
# 30  1988;AUS      NaN  1988       AUS
# 31  1987;AUS      NaN  1987       AUS
# 32  1986;AUS      NaN  1986       AUS
# 33  1985;AUS      NaN  1985       AUS
# 34  1984;AUS      NaN  1984       AUS
# 35  1982;USA      NaN  1982       USA
# 36  1981;USA      NaN  1981       USA
# 37  1980;USA      NaN  1980       USA
# 38  1979;USA      NaN  1979       USA
# 39  1978;USA      NaN  1978       USA
# 40  1977;USA      NaN  1977       USA
# 41  1972;USA      NaN  1972       USA
# 42  1970;USA      NaN  1970       USA
# 43  1968;USA      NaN  1968       USA
# 44  1966;USA      NaN  1966       USA
# 45  1965;USA      NaN  1965       USA
# 46  1964;AUS      NaN  1964       AUS

# %%
#Eliminamos las dos primeras columnas, ya que tenemos la información guardada correctamente en las siguientes después del split
campeonas.drop(["Year","Country"],axis=1,inplace = True)
display(campeonas)
# Out:
#    Years Countries
# 0   2019       USA
# 1   2018       AUS
# 2   2017       AUS
# 3   2016       AUS
# 4   2015       USA
# 5   2014       AUS
# 6   2013       USA
# 7   2012       AUS
# 8   2011       USA
# 9   2010       AUS
# 10  2009       AUS
# 11  2008       AUS
# 12  2007       AUS
# 13  2006       AUS
# 14  2005       AUS
# 15  2003       AUS
# 16  2002       AUS
# 17  2001       AUS
# 18  2000       AUS
# 19  1999       AUS
# 20  1998       AUS
# 21  1997       USA
# 22  1996       USA
# 23  1995       USA
# 24  1994       USA
# 25  1993       AUS
# 26  1992       AUS
# 27  1991       AUS
# 28  1990       AUS
# 29  1989       AUS
# 30  1988       AUS
# 31  1987       AUS
# 32  1986       AUS
# 33  1985       AUS
# 34  1984       AUS
# 35  1982       USA
# 36  1981       USA
# 37  1980       USA
# 38  1979       USA
# 39  1978       USA
# 40  1977       USA
# 41  1972       USA
# 42  1970       USA
# 43  1968       USA
# 44  1966       USA
# 45  1965       USA
# 46  1964       AUS
